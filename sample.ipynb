# %% [markdown]
# # This Jupyter Notebook is about Bayesian Data Analysis for neuroscience data
#
# ## Introduction
#
# This notebook is part of a 20-week internship project carried out at Ulster University.
# The main goal of the project is to make advanced Bayesian statistical models more accessible
# to experimental neuroscientists through user-friendly code, tutorials, and examples.
#
# Specifically, this notebook focuses on applying existing Bayesian models to neuroscience datasets
# using libraries in Python.
#
# ## Objectives
#
# 1. Apply the existing Bayesian models to a neuroscience dataset from scratch,
#    documenting each step as if it were for a beginner user.
#
# 2. Design a simple and reproducible analysis pipeline using PyMC.
#
# 3. Produce clear, well-documented code that can later be integrated into
#    an interactive tutorial or a web application.
#
# ## Tools and technologies
#
# - Python (main programming language)
# - PyMC (Bayesian modeling)
# - NumPy, pandas, matplotlib (data manipulation and visualization)
# - Jupyter Notebook (interactive documentation and prototyping)
#
# ## Author
#
# - Mathis DA SILVA
# - Ulster University Internship (July–December 2025)
# - Supervisors: Dr. Cian O'Donnell & Dr. Conor Houghton
#
# ## References
#
# - [Dataset from "Classification of psychedelics and psychoactive drugs based on brain-wide imaging of cellular c-Fos expression"](https://www.nature.com/articles/s41467-025-56850-6#Sec25)
# - [Hierarchical Bayesian modeling of multi-region brain cell count data](https://elifesciences.org/reviewed-preprints/102391v1)
# - [Statistical Rethinking 2023 PDF](https://civil.colorado.edu/~balajir/CVEN6833/bayes-resources/RM-StatRethink-Bayes.pdf)
# - [Statistical Rethinking 2023 Videos](https://www.youtube.com/watch?v=FdnMWdICdRs&list=PLDcUM9US4XdPz-KxHM4XHt7uUVGWWVSus)

# %% [markdown]
# ### Here, we can call libraries that we will use in this notebook.

# %%
import pandas as pd
import pymc as pm
import matplotlib.pyplot as plt
import math
import numpy as np
import seaborn as sns
import statistics as stats
# Out:
# WARNING (pytensor.configdefaults): g++ not available, if using conda: `conda install gxx`
# WARNING (pytensor.configdefaults): g++ not detected!  PyTensor will be unable to compile C-implementations and will default to Python. Performance may be severely degraded. To remove this warning, set PyTensor flags cxx to an empty string.

# %%
dataset1 = pd.read_excel('data/dataset_neuroscience_1.xlsx')

# %%
print("Dataset overview:\n")

# Overview the first few rows of the dataset 1
dataset1
# Out:
# Dataset overview:
#    abbreviation                                region name brain area  \
# 0           NaN                                        NaN        NaN
# 1           FRP               Frontal pole cerebral cortex     Cortex
# 2           ILA                           Infralimbic area     Cortex
# 3          ORBl                  Orbital area lateral part     Cortex
# 4          ORBm                   Orbital area medial part     Cortex
# 5         ORBvl            Orbital area ventrolateral part     Cortex
# 6           AId         Agranular insular area dorsal part     Cortex
# 7           AIp      Agranular insular area posterior part     Cortex
# 8           AIv        Agranular insular area ventral part     Cortex
# 9        RSPagl  Retrosplenial area lateral agranular part     Cortex
# 10         RSPd             Retrosplenial area dorsal part     Cortex
# 11         RSPv            Retrosplenial area ventral part     Cortex
# 12           PL                             Prelimbic area     Cortex
# 13         VISa                              Anterior area     Cortex
# 14          TEa                 Temporal association areas     Cortex
# 15         PERI                            Perirhinal area     Cortex
# 16          ECT                            Ectorhinal area     Cortex
# 17           PA                Posterior amygdalar nucleus     Cortex
# 18          BMA               Basomedial amygdalar nucleus     Cortex
# 19          BLA              Basolateral amygdalar nucleus     Cortex
# 20           LA                  Lateral amygdalar nucleus     Cortex
# 21          EPv          Endopiriform nucleus ventral part     Cortex
# 22          EPd           Endopiriform nucleus dorsal part     Cortex
# 23          CLA                                  Claustrum     Cortex
# 24        VISrl                  Rostrolateral visual area     Cortex
# 25         ACAv       Anterior cingulate area ventral part     Cortex
# 26         ACAd        Anterior cingulate area dorsal part     Cortex
# 27       VISpor                            Postrhinal area     Cortex
# 28          MOp                         Primary motor area     Cortex
# 29          MOs                       Secondary motor area     Cortex
# 30        SSp-n            Primary somatosensory area nose     Cortex
# 31      SSp-bfd    Primary somatosensory area barrel field     Cortex
# 32       SSp-ll      Primary somatosensory area lower limb     Cortex
# 33        SSp-m           Primary somatosensory area mouth     Cortex
# 34       SSp-ul      Primary somatosensory area upper limb     Cortex
# 35       SSp-tr           Primary somatosensory area trunk     Cortex
# 36       SSp-un      Primary somatosensory area unassigned     Cortex
# 37          SSs            Supplemental somatosensory area     Cortex
# 38           GU                            Gustatory areas     Cortex
# 39         VISC                              Visceral area     Cortex
# 40         AUDd                       Dorsal auditory area     Cortex
# 41         AUDp                      Primary auditory area     Cortex
# 42        AUDpo                    Posterior auditory area     Cortex
# 43         AUDv                      Ventral auditory area     Cortex
# 44        VISal                  Anterolateral visual area     Cortex
# 45        VISam                   Anteromedial visual area     Cortex
# 46         VISl                        Lateral visual area     Cortex
# 47         VISp                        Primary visual area     Cortex
# 48        VISpl                 Posterolateral visual area     Cortex
# 49        VISpm                  posteromedial visual area     Cortex
# 50        VISli                    Laterointermediate area     Cortex
#
#    5MEO1 count 5MEO2 count 5MEO3 count 5MEO4 count 5MEO5 count 5MEO6 count  \
# 0       Female      Female      Female        Male        Male        Male
# 1         9574        7781       17598        4425        7428        8302
# 2        12138        6742       28070        1685       15612       17191
# 3        48129       45849      120147       28655       40438       54206
# 4        17225        8551       34163        6330       14908       23250
# 5        32690       24460       58132       16015       24182       31926
# 6        27675       33674      142433       31908       29145       51636
# 7        14988       10315       35142       14553       11422       23320
# 8        11743       15781       62167       14611       13968       27256
# 9        26242        9762       36066       15133       11147       17832
# 10       22295        9280       33625       11297        8479       18555
# 11       19326        7706       30384        6428        9849       11236
# 12       35975       23459       57174        5694       29703       31896
# 13       15267       10201       32835       19709        5599       17278
# 14       52795       57293       96352       60874       38937       62307
# 15        3984        5134       15302        6161        4687        7805
# 16       21082       24997       48386       24437       13269       19703
# 17        4107        5481        9909        3429        4980        6765
# 39       7075      18840      16039       7360      26265
# 40       5558      13243       2104       6688      26176
# 41      13819      28532       6491      12521      69088
# 42       2936       9342       1794       5723      16404
# 43      13115      26219      12481      11845      64655
# 44       2163       5499       1911       3351      14103
# 45       1433      11695       3324       2464       7818
# 46       9411      17648       6233       8171      27497
# 47      40531      79044      25383      26324      93645
# 48       5412       7628       4328       5109       7855
# 49       6143      16134       7545       3723      11845
# 50       4595       8353       2832       4215      12914
#
# [51 rows x 67 columns]

# %% [markdown]
# #### Indications:
#
# Previously, we added the first dataset. In which, the first three columns represent brain regions with name and abbreviation. Others represent mice group by drugs as **MDMA**, **Ketamine**, **Fluoxetine**, ...
#
# There are **64 mice** in total, and each mouse has a value for each brain region. The values represent the number of cells expressing c-Fos, a marker of **neuronal activity**. Plus, there are **50 brain regions** in the dataset.

# %%
print("\nInformation about the dataset:\n")

# Overview the dataset information
dataset1.info()
# Out:
# Information about the dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 67 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   abbreviation    50 non-null     object
#  1   region name     50 non-null     object
#  2   brain area      50 non-null     object
#  3   5MEO1 count     51 non-null     object
#  4   5MEO2 count     51 non-null     object
#  5   5MEO3 count     51 non-null     object
#  6   5MEO4 count     51 non-null     object
#  7   5MEO5 count     51 non-null     object
#  8   5MEO6 count     51 non-null     object
#  9   5MEO7 count     51 non-null     object
#  10  5MEO8 count     51 non-null     object
#  11  6-F-DET1 count  51 non-null     object
#  12  6-F-DET2 count  51 non-null     object
#  13  6-F-DET3 count  51 non-null     object
#  14  6-F-DET4 count  51 non-null     object
#  15  6-F-DET5 count  51 non-null     object
#  16  6-F-DET6 count  51 non-null     object
#  17  6-F-DET7 count  51 non-null     object
#  18  6-F-DET8 count  51 non-null     object
#  19  A-SSRI1 count   51 non-null     object
#  20  A-SSRI2 count   51 non-null     object
#  21  A-SSRI3 count   51 non-null     object
#  22  A-SSRI4 count   51 non-null     object
#  23  A-SSRI5 count   51 non-null     object
#  24  A-SSRI6 count   51 non-null     object
#  25  A-SSRI7 count   51 non-null     object
#  26  A-SSRI8 count   51 non-null     object
#  27  C-SSRI1 count   51 non-null     object
#  28  C-SSRI2 count   51 non-null     object
#  29  C-SSRI3 count   51 non-null     object
#  30  C-SSRI4 count   51 non-null     object
#  31  C-SSRI5 count   51 non-null     object
#  32  C-SSRI6 count   51 non-null     object
#  33  C-SSRI7 count   51 non-null     object
#  34  C-SSRI8 count   51 non-null     object
#  35  KET1 count      51 non-null     object
#  36  KET2 count      51 non-null     object
#  37  KET3 count      51 non-null     object
#  38  KET4 count      51 non-null     object
#  39  KET5 count      51 non-null     object
#  40  KET6 count      51 non-null     object
#  41  KET7 count      51 non-null     object
#  42  KET8 count      51 non-null     object
#  43  MDMA1 count     51 non-null     object
#  44  MDMA2 count     51 non-null     object
#  45  MDMA3 count     51 non-null     object
#  46  MDMA4 count     51 non-null     object
#  47  MDMA5 count     51 non-null     object
#  48  MDMA6 count     51 non-null     object
#  49  MDMA7 count     51 non-null     object
#  50  MDMA8 count     51 non-null     object
#  51  PSI1 count      51 non-null     object
#  52  PSI2 count      51 non-null     object
#  53  PSI3 count      51 non-null     object
#  54  PSI4 count      51 non-null     object
#  55  PSI5 count      51 non-null     object
#  56  PSI6 count      51 non-null     object
#  57  PSI7 count      51 non-null     object
#  58  PSI8 count      51 non-null     object
#  59  SAL1 count      51 non-null     object
#  60  SAL2 count      51 non-null     object
#  61  SAL3 count      51 non-null     object
#  62  SAL4 count      51 non-null     object
#  63  SAL5 count      51 non-null     object
#  64  SAL6 count      51 non-null     object
#  65  SAL7 count      51 non-null     object
#  66  SAL8 count      51 non-null     object
# dtypes: object(67)
# memory usage: 26.8+ KB

# %% [markdown]
# #### Indications:
#
# Here, we have an overview of the dataset (1) information.

# %%
print("\nDescriptive statistics of the dataset:\n")

# Overview the descriptive statistics of the dataset
dataset1.describe()
# Out:
# Descriptive statistics of the dataset:
#        abbreviation                   region name brain area 5MEO1 count  \
# count            50                            50         50          51
# unique           50                            50          1          51
# top             FRP  Frontal pole cerebral cortex     Cortex      Female
# freq              1                             1         50           1
#
#        5MEO2 count 5MEO3 count 5MEO4 count 5MEO5 count 5MEO6 count  \
# count           51          51          51          51          51
# unique          51          51          51          51          51
# top         Female      Female        Male        Male        Male
# freq             1           1           1           1           1
#
#        5MEO7 count  ... PSI7 count PSI8 count SAL1 count SAL2 count  \
# count           51  ...         51         51         51         51
# unique          51  ...         50         51         51         51
# top        Unknown  ...       7447    Unknown     Female     Female
# freq             1  ...          2          1          1          1
#
#        SAL3 count SAL4 count SAL5 count SAL6 count SAL7 count  SAL8 count
# count          51         51         51         51         51          51
# unique         51         51         51         51         51          51
# top        Female       Male       Male       Male    Unknown     Unknown
# freq            1          1          1          1          1           1
#
# [4 rows x 67 columns]

# %% [markdown]
# #### Indications:

# %% [markdown]
# ### Poisson model
# ---

# %%
with pm.Model() as poisson_model:

    # Parameters for the Poisson model
    theta_rg = pm.Normal("Normal model",mu=5,sigma=2)
    tau_rg = pm.HalfNormal("HalfNormal model", sigma=math.log(1.05))

# %% [markdown]
# ### Horseshoe model
# ---

# %%
with pm.Model() as horseshoe_model:

    # Parameters for the Horseshoe model
    theta_rg = pm.Normal("Normal model",mu = 5,sigma = 2)
    tau_rg = pm.HalfNormal("HalfNormal model", sigma = math.log(1.05))
    k_i = pm.HalfNormal("HalfNormal model", sigma = 1)

# %% [markdown]
# ### Zero-inflated model
# ---

# %%
with pm.Model() as zero_inflated_model:

    # Parameters for Zero-inflated model
    theta_rg = pm.Normal("Normal model", mu = 5, sigma = 2)
    tau_rg = pm.HalfNormal("HalfNormal model", sigma = math.log(1.05))
